# %%
using LinearAlgebra
using Plots

# %%
a1, a2 = ([.0624;-0.001],[-0.001,15.999])
# Out:
# ([0.0624, -0.001], [-0.001, 15.999])

# %%
a3 = a1 + a2
a5 = -a2
a4 = -a1
# Out:
# 2-element Vector{Float64}:
#  -0.0624
#   0.001

# %%
[a4 a3]inv([a1 a2])
# Out:
# 2×2 Matrix{Float64}:
#  -0.999939   0.00377524
#   0.0320503  0.999939

# %%
[a4 a5]inv([a1 a2])
# Out:
# 2×2 Matrix{Float64}:
#  -1.0   1.35525e-20
#   0.0  -1.0

# %%
[a1 a5]inv([a1 a2])
# Out:
# 2×2 Matrix{Float64}:
#   1.0         0.000125008
#  -0.0320513  -1.0

# %%
norm.([a2,a3])
# Out:
# 2-element Vector{Float64}:
#  15.999000031251954
#  15.998117825544355

# %%
1/16
# Out:
# 0.0625

# %%
x=0:.01:3
# Out:
# 0.0:0.01:3.0

# %%
plot(x,sqrt.(1 .+x.^2),dpi=300,legend=:none)

# %%
h1=[1, 0]
h2=[1/2, √3/2]
# Out:
# 2-element Vector{Float64}:
#  0.5
#  0.8660254037844386

# %%
[h1 h2]
# Out:
# 2×2 Matrix{Float64}:
#  1.0  0.5
#  0.0  0.866025

# %%
norm(h1+h2)
# Out:
# 1.7320508075688772

# %%
norm(h2)
# Out:
# 0.9999999999999999

# %%
norm(-h1+h2)
# Out:
# 0.9999999999999999

# %%
x=π/4:.01:3π/4
plot(x,cos.(x),dpi=300)

# %%
x=57*π/180:.001:63*π/180
@show π/3
plot(x*180/π,cos.(x),dpi=300)
# Out:
# π / 3 = 1.0471975511965976

# %%
x=117*π/180:.001:123*π/180
@show π/3
plot(x*180/π,cos.(x),dpi=300)
# Out:
# π / 3 = 1.0471975511965976

# %%
# if isapprox(|cosθ|,.5,atol=.02)
x=117*π/180:.001:123*π/180
plot!(x*180/π,.06*isapprox.(abs.(cos.(x)),.5,rtol=.03).-.525,dpi=300)

# %%
?append!
# Out:
# search: append!
#   append!(collection, collections...) -> collection.
#
#   For an ordered container collection, add the elements of each collections to
#   the end of it.
#
#   │ Julia 1.6
#   │
#   │  Specifying multiple collections to be appended requires at least
#   │  Julia 1.6.
#
#   Examples
#   ≡≡≡≡≡≡≡≡≡≡
#
#   julia> append!([1], [2, 3])
#   3-element Vector{Int64}:
#    1
#    2
#    3
#
#   julia> append!([1, 2, 3], [4, 5], [6])
#   6-element Vector{Int64}:
#    1
#    2
#    3
#    4
#    5
#    6
#
#   Use push! to add individual items to collection which are not already
#   themselves in another collection. The result of the preceding example is
#   equivalent to push!([1, 2, 3], 4, 5, 6).
#
#   See sizehint! for notes about the performance model.
#
#   ────────────────────────────────────────────────────────────────────────────
#
#   append!(cb::CircularBuffer, datavec::AbstractVector)
#
#   Push at most last capacity items.
